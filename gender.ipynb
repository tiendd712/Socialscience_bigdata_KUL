# %%
pip install deepface
# Out:
# Collecting deepface
#   Downloading https://files.pythonhosted.org/packages/48/ae/b3e7704245ffa505e0733aadcb5794220e4a5b72941c51ee44548483c1cb/deepface-0.0.79-py3-none-any.whl (49kB)
#      |████████████████████████████████| 51kB 139kB/s eta 0:00:01
# Collecting retina-face>=0.0.1 (from deepface)
#   Downloading https://files.pythonhosted.org/packages/35/15/3082429720efa372b3a4a214583f69805227af18dba930b89abefe5ea066/retina_face-0.0.13-py3-none-any.whl
# Requirement already satisfied: fire>=0.4.0 in /opt/anaconda3/lib/python3.7/site-packages (from deepface) (0.4.0)
# Collecting opencv-python>=4.5.5.64 (from deepface)
#   Downloading https://files.pythonhosted.org/packages/ec/30/9b24a6e7021447788fa89ae5c215fb5c17b893585ddc6ac553632cc1b761/opencv_python-4.8.0.74-cp37-abi3-macosx_10_16_x86_64.whl (54.6MB)
#      |████████████████████████████████| 54.6MB 37.3MB/s eta 0:00:01   |█▉                              | 3.2MB 8.3MB/s eta 0:00:07     |██                              | 3.6MB 8.3MB/s eta 0:00:07:00:06ta 0:01:31
# Collecting keras>=2.2.0 (from deepface)
#   Downloading https://files.pythonhosted.org/packages/de/44/bf1b0eef5b13e6201aef076ff34b91bc40aace8591cd273c1c2a94a9cc00/keras-2.11.0-py2.py3-none-any.whl (1.7MB)
#      |████████████████████████████████| 1.7MB 19.2MB/s eta 0:00:01
# Requirement already satisfied: pandas>=0.23.4 in /opt/anaconda3/lib/python3.7/site-packages (from deepface) (1.3.5)
# Requirement already satisfied: tqdm>=4.30.0 in /opt/anaconda3/lib/python3.7/site-packages (from deepface) (4.65.0)
# Collecting mtcnn>=0.1.0 (from deepface)
#   Downloading https://files.pythonhosted.org/packages/09/d1/2a4269e387edb97484157b872fa8a1953b53dcafbe4842a1967f549ac5ea/mtcnn-0.1.1-py3-none-any.whl (2.3MB)
#      |████████████████████████████████| 2.3MB 17.1MB/s eta 0:00:01
# Collecting gdown>=3.10.1 (from deepface)
#   Downloading https://files.pythonhosted.org/packages/e7/38/e3393edb5fd157abaa54292f31251f8c2ff739673f535990f8a43e69b9dd/gdown-4.7.1-py3-none-any.whl
# Requirement already satisfied: Flask>=1.1.2 in /opt/anaconda3/lib/python3.7/site-packages (from deepface) (2.2.3)
# Collecting gunicorn>=20.1.0 (from deepface)
#   Using cached https://files.pythonhosted.org/packages/e4/dd/5b190393e6066286773a67dfcc2f9492058e9b57c4867a95f1ba5caf0a83/gunicorn-20.1.0-py3-none-any.whl
# Requirement already satisfied: Pillow>=5.2.0 in /opt/anaconda3/lib/python3.7/site-packages (from deepface) (9.4.0)
# Requirement already satisfied: numpy>=1.14.0 in /opt/anaconda3/lib/python3.7/site-packages (from deepface) (1.21.6)
# Requirement already satisfied: tensorflow>=1.9.0 in /opt/anaconda3/lib/python3.7/site-packages (from deepface) (2.3.1)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.7/site-packages (from fire>=0.4.0->deepface) (1.16.0)
# Requirement already satisfied: termcolor in /opt/anaconda3/lib/python3.7/site-packages (from fire>=0.4.0->deepface) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/anaconda3/lib/python3.7/site-packages (from pandas>=0.23.4->deepface) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/anaconda3/lib/python3.7/site-packages (from pandas>=0.23.4->deepface) (2022.7.1)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.7/site-packages (from gdown>=3.10.1->deepface) (3.0.12)
# Requirement already satisfied: requests[socks] in /opt/anaconda3/lib/python3.7/site-packages (from gdown>=3.10.1->deepface) (2.28.2)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/lib/python3.7/site-packages (from gdown>=3.10.1->deepface) (4.8.0)
# Requirement already satisfied: click>=8.0 in /opt/anaconda3/lib/python3.7/site-packages (from Flask>=1.1.2->deepface) (8.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in /opt/anaconda3/lib/python3.7/site-packages (from Flask>=1.1.2->deepface) (2.1.2)
# Collecting Jinja2>=3.0 (from Flask>=1.1.2->deepface)
#   Using cached https://files.pythonhosted.org/packages/bc/c3/f068337a370801f372f2f8f6bad74a5c140f6fda3d9de154052708dd3c65/Jinja2-3.1.2-py3-none-any.whl
# Requirement already satisfied: Werkzeug>=2.2.2 in /opt/anaconda3/lib/python3.7/site-packages (from Flask>=1.1.2->deepface) (2.2.3)
# Requirement already satisfied: importlib-metadata>=3.6.0; python_version < "3.10" in /opt/anaconda3/lib/python3.7/site-packages (from Flask>=1.1.2->deepface) (5.2.0)
# Requirement already satisfied: setuptools>=3.0 in /opt/anaconda3/lib/python3.7/site-packages (from gunicorn>=20.1.0->deepface) (67.6.0)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow>=1.9.0->deepface) (2.10.0)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow>=1.9.0->deepface) (1.1.2)
# Requirement already satisfied: astunparse==1.6.3 in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: google-pasta>=0.1.8 in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: wrapt>=1.11.1 in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow>=1.9.0->deepface) (1.15.0)
# Requirement already satisfied: tensorflow-estimator<2.4.0,>=2.3.0 in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow>=1.9.0->deepface) (2.3.0)
# Requirement already satisfied: grpcio>=1.8.6 in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow>=1.9.0->deepface) (1.33.1)
# Requirement already satisfied: tensorboard<3,>=2.3.0 in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow>=1.9.0->deepface) (2.3.0)
# Requirement already satisfied: absl-py>=0.7.0 in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow>=1.9.0->deepface) (0.10.0)
# Requirement already satisfied: protobuf>=3.9.2 in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow>=1.9.0->deepface) (4.22.4)
# Requirement already satisfied: wheel>=0.26 in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow>=1.9.0->deepface) (0.40.0)
# Requirement already satisfied: gast==0.3.3 in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow>=1.9.0->deepface) (0.3.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow>=1.9.0->deepface) (3.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.7/site-packages (from requests[socks]->gdown>=3.10.1->deepface) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.7/site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.7/site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.7/site-packages (from requests[socks]->gdown>=3.10.1->deepface) (3.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /opt/anaconda3/lib/python3.7/site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: soupsieve>=1.2 in /opt/anaconda3/lib/python3.7/site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (1.9.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.7/site-packages (from Jinja2>=3.0->Flask>=1.1.2->deepface) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/lib/python3.7/site-packages (from importlib-metadata>=3.6.0; python_version < "3.10"->Flask>=1.1.2->deepface) (3.15.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /opt/anaconda3/lib/python3.7/site-packages (from importlib-metadata>=3.6.0; python_version < "3.10"->Flask>=1.1.2->deepface) (4.5.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /opt/anaconda3/lib/python3.7/site-packages (from tensorboard<3,>=2.3.0->tensorflow>=1.9.0->deepface) (0.4.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /opt/anaconda3/lib/python3.7/site-packages (from tensorboard<3,>=2.3.0->tensorflow>=1.9.0->deepface) (1.22.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /opt/anaconda3/lib/python3.7/site-packages (from tensorboard<3,>=2.3.0->tensorflow>=1.9.0->deepface) (1.7.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/anaconda3/lib/python3.7/site-packages (from tensorboard<3,>=2.3.0->tensorflow>=1.9.0->deepface) (3.3.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/anaconda3/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow>=1.9.0->deepface) (1.3.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /opt/anaconda3/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=1.9.0->deepface) (4.1.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=1.9.0->deepface) (0.2.7)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.5" in /opt/anaconda3/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=1.9.0->deepface) (4.6)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/anaconda3/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow>=1.9.0->deepface) (3.2.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/anaconda3/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=1.9.0->deepface) (0.4.8)
# ERROR: nitter-scraper 0.5.0 has requirement jinja2<3.0.0,>=2.11.2, but you'll have jinja2 3.1.2 which is incompatible.
# ERROR: azureml-train-automl-runtime 1.24.0 has requirement jinja2<=2.11.2, but you'll have jinja2 3.1.2 which is incompatible.
# ERROR: azureml-train-automl-runtime 1.24.0 has requirement lightgbm<=2.3.0,>=2.0.11, but you'll have lightgbm 3.3.5 which is incompatible.
# ERROR: azureml-train-automl-runtime 1.24.0 has requirement numpy<1.19.0,>=1.16.0, but you'll have numpy 1.21.6 which is incompatible.
# ERROR: azureml-train-automl-runtime 1.24.0 has requirement pandas<1.0.0,>=0.21.0, but you'll have pandas 1.3.5 which is incompatible.
# ERROR: azureml-train-automl-runtime 1.24.0 has requirement scikit-learn<0.23.0,>=0.19.0, but you'll have scikit-learn 1.0.2 which is incompatible.
# ERROR: azureml-train-automl-runtime 1.24.0 has requirement scipy<=1.5.2,>=1.0.0, but you'll have scipy 1.7.3 which is incompatible.
# ERROR: azureml-train-automl-runtime 1.24.0 has requirement statsmodels<=0.10.2,>=0.9.0, but you'll have statsmodels 0.13.5 which is incompatible.
# ERROR: azureml-defaults 1.24.0 has requirement flask==1.0.3, but you'll have flask 2.2.3 which is incompatible.
# ERROR: azureml-defaults 1.24.0 has requirement gunicorn==19.9.0, but you'll have gunicorn 20.1.0 which is incompatible.
# ERROR: azureml-defaults 1.24.0 has requirement werkzeug<=1.0.1,>=0.16.1, but you'll have werkzeug 2.2.3 which is incompatible.
# Installing collected packages: opencv-python, gdown, retina-face, keras, mtcnn, gunicorn, deepface, Jinja2
#   Found existing installation: opencv-python 4.4.0.44
#     Uninstalling opencv-python-4.4.0.44:
#       Successfully uninstalled opencv-python-4.4.0.44
#   Found existing installation: gunicorn 19.9.0
#     Uninstalling gunicorn-19.9.0:
#       Successfully uninstalled gunicorn-19.9.0
#   Found existing installation: Jinja2 2.11.3
#     Uninstalling Jinja2-2.11.3:
#       Successfully uninstalled Jinja2-2.11.3
# Successfully installed Jinja2-3.1.2 deepface-0.0.79 gdown-4.7.1 gunicorn-20.1.0 keras-2.11.0 mtcnn-0.1.1 opencv-python-4.8.0.74 retina-face-0.0.13
# Note: you may need to restart the kernel to use updated packages.

# %%
from deepface import DeepFace
import cv2
from urllib.request import urlopen
import matplotlib.pyplot as plt
import numpy as np
from io import BytesIO
import requests

# %%
def url_to_image(url, readFlag=cv2.IMREAD_COLOR):
    # download the image, convert it to a NumPy array, and then read
    # it into OpenCV format
    resp = urlopen(url)
    image = np.asarray(bytearray(resp.read()), dtype="uint8")
    image = cv2.imdecode(image, readFlag)

    # return the image
    return image

# %%
image_url = "https://media.licdn.com/dms/image/C5603AQG2NxfDHtxMbQ/profile-displayphoto-shrink_800_800/0/1638158783981?e=1694649600&v=beta&t=2E-tnm7SmY94LWg8jr0RDAdiFd5FBCL4W_bhZAcKG0s"
img1 = url_to_image(image_url)
plt.imshow(img1[:,:,::-1])
plt.show()

# %%
result = DeepFace.analyze(img1, actions=['gender'])
# Out:
# Action: gender: 100%|██████████| 1/1 [00:01<00:00,  1.63s/it]

# %%
print(result[0]['dominant_gender'])
# Out:
# Man

# %%
image_url = "https://media.licdn.com/dms/image/D5603AQGdt0FFv_IQWA/profile-displayphoto-shrink_800_800/0/1680467403682?e=1694649600&v=beta&t=9AHAYdjCE97-CoJbypn8crFbZHSpD9QnVzywc-dYS5w"
img2 = url_to_image(image_url)
plt.imshow(img2[:,:,::-1])
plt.show()

# %%
result = DeepFace.analyze(img2, actions=['gender']) # I tried enforce_detection = False and the result returns is Men...
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/wz/ss5c6j393vv1vr0xc8yky_680000gn/T/ipykernel_27850/2988533841.py in <module>
# ----> 1 result = DeepFace.analyze(img2, actions=['gender'])
#
# /opt/anaconda3/lib/python3.7/site-packages/deepface/DeepFace.py in analyze(img_path, actions, enforce_detection, detector_backend, align, silent)
#     317         grayscale=False,
#     318         enforce_detection=enforce_detection,
# --> 319         align=align,
#     320     )
#     321
#
# /opt/anaconda3/lib/python3.7/site-packages/deepface/commons/functions.py in extract_faces(img, target_size, detector_backend, grayscale, enforce_detection, align)
#     114     if len(face_objs) == 0 and enforce_detection is True:
#     115         raise ValueError(
# --> 116             "Face could not be detected. Please confirm that the picture is a face photo "
#     117             + "or consider to set enforce_detection param to False."
#     118         )
#
# ValueError: Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.

# %%
result
# Out:
# [{'gender': {'Woman': 21.617139875888824, 'Man': 78.3828616142273},
#   'dominant_gender': 'Man',
#   'region': {'x': 0, 'y': 0, 'w': 800, 'h': 800}}]

# %%
img3 = cv2.imread("/Users/anhphuong/Pictures/thaiha.jpeg")
plt.imshow(img3[:,:,::-1])

# %%
result = DeepFace.analyze(img3, actions=['gender'])
# Out:
# Action: gender: 100%|██████████| 1/1 [00:03<00:00,  3.16s/it]
# Action: gender: 100%|██████████| 1/1 [00:00<00:00,  2.53it/s]
# Action: gender: 100%|██████████| 1/1 [00:00<00:00,  2.29it/s]

# %%
result
# Out:
# [{'gender': {'Woman': 12.72660493850708, 'Man': 87.27339506149292},
#   'dominant_gender': 'Man',
#   'region': {'x': 539, 'y': 29, 'w': 217, 'h': 217}},
#  {'gender': {'Woman': 96.51986360549927, 'Man': 3.480135276913643},
#   'dominant_gender': 'Woman',
#   'region': {'x': 274, 'y': 141, 'w': 222, 'h': 222}},
#  {'gender': {'Woman': 10.377749800682068, 'Man': 89.62225317955017},
#   'dominant_gender': 'Man',
#   'region': {'x': 701, 'y': 267, 'w': 56, 'h': 56}}]

# %%
image_url = "https://media.licdn.com/dms/image/D4E03AQETmKjqE5Yjqg/profile-displayphoto-shrink_800_800/0/1669558810767?e=1694649600&v=beta&t=B26LB6jAiXgKCGeg_EhAAd21TPj_j97s6b6_C6mIKJI"
img4 = url_to_image(image_url)
plt.imshow(img4[:,:,::-1])
plt.show()

# %%
result = DeepFace.analyze(img4, actions=['gender'])
# Out:
# Action: gender: 100%|██████████| 1/1 [00:02<00:00,  2.96s/it]

# %%
result
# Out:
# [{'gender': {'Woman': 79.21903133392334, 'Man': 20.78096568584442},
#   'dominant_gender': 'Woman',
#   'region': {'x': 284, 'y': 108, 'w': 233, 'h': 233}}]

# %%
image_url = "https://media.licdn.com/dms/image/C4D03AQHdP6qsEhhyiA/profile-displayphoto-shrink_800_800/0/1652367993709?e=1694649600&v=beta&t=u-j3hyT9PY1_a6wS48BkC-5dLlnpWt1LQje9t6q9TXE"
img5 = url_to_image(image_url)
plt.imshow(img5[:,:,::-1])
plt.show()

# %%
result = DeepFace.analyze(img5, actions=['gender'])
# Out:
# Action: gender: 100%|██████████| 1/1 [00:04<00:00,  4.31s/it]

# %%
result
# Out:
# [{'gender': {'Woman': 0.060606386978179216, 'Man': 99.93939399719238},
#   'dominant_gender': 'Man',
#   'region': {'x': 305, 'y': 202, 'w': 153, 'h': 153}}]
