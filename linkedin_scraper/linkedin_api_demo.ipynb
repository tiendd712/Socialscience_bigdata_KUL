# %%
pip install linkedin_api

# %%
from linkedin_api import Linkedin

# Authenticate using any Linkedin account credentials
api = Linkedin('tiemsachgacxep@gmail.com', 'leuven@2023')

# %%
# This profile name is already scraped (check stat_url on github)
api.get_profile('maxime-defauw-a08a82130')
# Out:
# {'industryName': 'Computer Software',
#  'lastName': 'Defauw',
#  'locationName': 'United States',
#  'student': False,
#  'geoCountryName': 'United States',
#  'geoCountryUrn': 'urn:li:fs_geo:103644278',
#  'geoLocationBackfilled': False,
#  'elt': False,
#  'industryUrn': 'urn:li:fs_industry:4',
#  'firstName': 'Maxime',
#  'entityUrn': 'urn:li:fs_profile:ACoAACAx0ygBwsmVJfUhzG2JrTV9xaPp6FXhQxU',
#  'geoLocation': {'geoUrn': 'urn:li:fs_geo:102571732'},
#  'geoLocationName': 'New York, New York',
#  'location': {'basicLocation': {'countryCode': 'us'}},
#  'headline': 'Software @ Palantir',
#  'displayPictureUrl': 'https://media.licdn.com/dms/image/C5603AQEmk71yfnrSgw/profile-displayphoto-shrink_',
#  'img_100_100': '100_100/0/1522157437325?e=1688601600&v=beta&t=nchJXgGn8YKPxfOlloK4QrEPBDaSky8gKaPwdYe97lI',
#  'img_200_200': '200_200/0/1522157437325?e=1688601600&v=beta&t=Juhwreg0uV9slsd2x9ChFjCKAcCq1Coj8xU20epZTOk',
# ...

# %%
api.get_profile_skills('maxime-defauw-a08a82130')
# Out:
# [{'name': 'Palantir Foundry'},
#  {'name': 'Leadership',
#   'standardizedSkillUrn': 'urn:li:fs_miniSkill:154',
#   'standardizedSkill': {'name': 'Leadership',
#    'entityUrn': 'urn:li:fs_miniSkill:154'}},
#  {'name': 'Programming'},
#  {'name': 'Computer Science'},
#  {'name': 'Electrical Engineering'},
#  {'name': 'Statistics'},
#  {'name': 'Machine Learning'},
#  {'name': 'Corporate Finance'},
#  {'name': 'Macroeconomics'},
#  {'name': 'HR Management'},
#  {'name': 'Mechanics'},
#  {'name': 'Object-Oriented Programming (OOP)'},
#  {'name': 'Computer Networks'},
#  {'name': 'Semiconductors'},
#  {'name': 'Blockchain'},
#  {'name': 'Swift (Programming Language)'},
#  {'name': 'Python (Programming Language)'},
#  {'name': 'SQL'},
#  {'name': 'LaTeX'},
#  {'name': 'Xcode'},
#  {'name': 'MATLAB'},
#  {'name': 'Verilog'},
#  {'name': 'Java'},
#  {'name': 'Databases'},
#  {'name': 'Management'},
#  {'name': 'Linear Algebra'},
#  {'name': 'Internet of Things (IoT)'},
# ...

# %%
api.get_profile_connections('maxime-defauw-a08a82130')
# Out:
# []

# %%
api.get_profile_network_info('maxime-defauw-a08a82130')
# Out:
# {'distance': {'value': 'OUT_OF_NETWORK',
#   '$type': 'com.linkedin.voyager.common.MemberDistance'},
#  'entityUrn': 'urn:li:fs_profileNetworkInfo:ACoAACAx0ygBwsmVJfUhzG2JrTV9xaPp6FXhQxU',
#  'following': False,
#  'followable': True,
#  '*followingInfo': 'urn:li:fs_followingInfo:urn:li:member:ACoAACAx0ygBwsmVJfUhzG2JrTV9xaPp6FXhQxU',
#  'followersCount': 1170,
#  'connectionsCount': 500,
#  '$type': 'com.linkedin.voyager.identity.profile.ProfileNetworkInfo'}

# %%
api.get_profile_posts('maxime-defauw-a08a82130')
# Out:
# [{'actor': {'urn': 'urn:li:member:540136232',
#    'image': {'accessibilityTextAttributes': [],
#     'attributes': [{'sourceType': 'PROFILE_PICTURE',
#       'miniProfile': {'firstName': 'Maxime',
#        'lastName': 'Defauw',
#        'dashEntityUrn': 'urn:li:fsd_profile:ACoAACAx0ygBwsmVJfUhzG2JrTV9xaPp6FXhQxU',
#        'occupation': 'Software @ Palantir',
#        'objectUrn': 'urn:li:member:540136232',
#        'entityUrn': 'urn:li:fs_miniProfile:ACoAACAx0ygBwsmVJfUhzG2JrTV9xaPp6FXhQxU',
#        'publicIdentifier': 'maxime-defauw-a08a82130',
#        'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 100,
#            'fileIdentifyingUrlPathSegment': '100_100/0/1522157437325?e=1688601600&v=beta&t=nchJXgGn8YKPxfOlloK4QrEPBDaSky8gKaPwdYe97lI',
#            'expiresAt': 1688601600000,
#            'height': 100},
#           {'width': 200,
# ...
